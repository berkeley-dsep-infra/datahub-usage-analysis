# %%
import seaborn
import statsmodels
import transformers
import lxml
import geopandas
import geopy
import lifelines
import pycountry

# %%
help(pycountry)
# Out:
# Help on package pycountry:
#
# NAME
#     pycountry - pycountry
#
# PACKAGE CONTENTS
#     db
#
# CLASSES
#     pycountry.db.Data(builtins.object)
#         Subdivision
#     pycountry.db.Database(builtins.object)
#         Currencies
#         ExistingCountries
#             HistoricCountries
#         LanguageFamilies
#         Languages
#         Scripts
#         Subdivisions
#
#     class Currencies(pycountry.db.Database)
#      |  Currencies(filename)
#      |
#      |  Provides access to an ISO 4217 database (Currencies).
#      |
#      |  Method resolution order:
#      |      Currencies
#      |      pycountry.db.Database
#      |      builtins.object
#      |
#      |  Data and other attributes defined here:
#      |
#      |  data_class_name = 'Currency'
#      |
#      |  root_key = '4217'
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from pycountry.db.Database:
#      |
# ...
